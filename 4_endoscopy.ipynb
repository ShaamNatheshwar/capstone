# %%
#importing the essential libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
from tensorflow.keras.preprocessing import image

# %%
train_set="C:/Users/jpsha/Documents/capstone/etrain"
val_set="C:/Users/jpsha/Documents/capstone/eval"
test_set="C:/Users/jpsha/Documents/capstone/etest"

# %%
train_datagen = image.ImageDataGenerator(
    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)
validation_datagen= image.ImageDataGenerator(    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1)
test_datagen= image.ImageDataGenerator(    rotation_range=15,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

# %%
train_generator = train_datagen.flow_from_directory(
    train_set,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical')
validation_generator = validation_datagen.flow_from_directory(
    val_set,
    target_size = (224,224),
    batch_size = 16,
    shuffle=True,
    class_mode = 'categorical')
test_generator = test_datagen.flow_from_directory(
    test_set,
    target_size = (224,224),
    batch_size = 16,
    class_mode = 'categorical')
# Out:
# Found 3200 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.

# %%
train_generator.class_indices
# Out:
# {'0_normal': 0, '1_ulcerative_colitis': 1, '2_polyps': 2, '3_esophagitis': 3}

# %%
from tensorflow.keras import regularizers
from keras.regularizers import l2

base_model = tf.keras.applications.EfficientNetB2(weights='imagenet', input_shape=(224,224,3), include_top=False)

for layer in base_model.layers:
    layer.trainable=False
model = Sequential()
model.add(base_model)
#model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(GaussianNoise(0.35))
model.add(GlobalAveragePooling2D())
model.add(Dense(256,activation='relu'))
model.add(BatchNormalization())
model.add(GaussianNoise(0.35))
model.add(Dropout(0.2))
model.add(Dense(4, activation='softmax'))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb2 (Functional)  (None, 7, 7, 1408)       7768569
#
#  gaussian_noise (GaussianNoi  (None, 7, 7, 1408)       0
#  se)
#
#  global_average_pooling2d (G  (None, 1408)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               360704
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  gaussian_noise_1 (GaussianN  (None, 256)              0
#  oise)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 8,131,325
# Trainable params: 362,244
# Non-trainable params: 7,769,081
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy','Precision','Recall','AUC'])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=20, #steps_per_epoch= training_images/batch_size= 3200/32<=200
    epochs = 20, #own choice
    validation_data = validation_generator
)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 119s 6s/step - loss: 0.5925 - accuracy: 0.8062 - precision: 0.8257 - recall: 0.7844 - auc: 0.9455 - val_loss: 0.3903 - val_accuracy: 0.8755 - val_precision: 0.9150 - val_recall: 0.8240 - val_auc: 0.9806
# Epoch 2/20
# 20/20 [==============================] - 106s 6s/step - loss: 0.2963 - accuracy: 0.9094 - precision: 0.9204 - recall: 0.9031 - auc: 0.9843 - val_loss: 0.3219 - val_accuracy: 0.8990 - val_precision: 0.9269 - val_recall: 0.8565 - val_auc: 0.9849
# Epoch 3/20
# 20/20 [==============================] - 105s 5s/step - loss: 0.2849 - accuracy: 0.9031 - precision: 0.9082 - recall: 0.8969 - auc: 0.9878 - val_loss: 0.3122 - val_accuracy: 0.8900 - val_precision: 0.9170 - val_recall: 0.8620 - val_auc: 0.9841
# Epoch 4/20
# 20/20 [==============================] - 105s 5s/step - loss: 0.2627 - accuracy: 0.9125 - precision: 0.9204 - recall: 0.9031 - auc: 0.9845 - val_loss: 0.3046 - val_accuracy: 0.8845 - val_precision: 0.9041 - val_recall: 0.8625 - val_auc: 0.9843
# Epoch 5/20
# 20/20 [==============================] - 109s 6s/step - loss: 0.2495 - accuracy: 0.9062 - precision: 0.9060 - recall: 0.9031 - auc: 0.9898 - val_loss: 0.3669 - val_accuracy: 0.8640 - val_precision: 0.8949 - val_recall: 0.8385 - val_auc: 0.9770
# Epoch 6/20
# 20/20 [==============================] - 110s 6s/step - loss: 0.1834 - accuracy: 0.9375 - precision: 0.9464 - recall: 0.9375 - auc: 0.9938 - val_loss: 0.3368 - val_accuracy: 0.8765 - val_precision: 0.8984 - val_recall: 0.8535 - val_auc: 0.9804
# Epoch 7/20
# 20/20 [==============================] - 109s 6s/step - loss: 0.2075 - accuracy: 0.9312 - precision: 0.9393 - recall: 0.9187 - auc: 0.9916 - val_loss: 0.2543 - val_accuracy: 0.9050 - val_precision: 0.9182 - val_recall: 0.8920 - val_auc: 0.9887
# Epoch 8/20
# 20/20 [==============================] - 110s 6s/step - loss: 0.1438 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9961 - val_loss: 0.2578 - val_accuracy: 0.9035 - val_precision: 0.9157 - val_recall: 0.8965 - val_auc: 0.9871
# Epoch 9/20
# 20/20 [==============================] - 113s 6s/step - loss: 0.0991 - accuracy: 0.9500 - precision: 0.9558 - recall: 0.9469 - auc: 0.9982 - val_loss: 0.2771 - val_accuracy: 0.8920 - val_precision: 0.9024 - val_recall: 0.8825 - val_auc: 0.9870
# Epoch 10/20
# 20/20 [==============================] - 120s 6s/step - loss: 0.1870 - accuracy: 0.9281 - precision: 0.9365 - recall: 0.9219 - auc: 0.9930 - val_loss: 0.3088 - val_accuracy: 0.8820 - val_precision: 0.8890 - val_recall: 0.8730 - val_auc: 0.9835
# Epoch 11/20
# 20/20 [==============================] - 110s 6s/step - loss: 0.1261 - accuracy: 0.9563 - precision: 0.9590 - recall: 0.9500 - auc: 0.9968 - val_loss: 0.2374 - val_accuracy: 0.9105 - val_precision: 0.9176 - val_recall: 0.9025 - val_auc: 0.9900
# Epoch 12/20
# 20/20 [==============================] - 110s 6s/step - loss: 0.1241 - accuracy: 0.9625 - precision: 0.9623 - recall: 0.9563 - auc: 0.9958 - val_loss: 0.1999 - val_accuracy: 0.9270 - val_precision: 0.9327 - val_recall: 0.9220 - val_auc: 0.9918
# Epoch 13/20
# 20/20 [==============================] - 111s 6s/step - loss: 0.1466 - accuracy: 0.9531 - precision: 0.9590 - recall: 0.9500 - auc: 0.9958 - val_loss: 0.2129 - val_accuracy: 0.9255 - val_precision: 0.9299 - val_recall: 0.9220 - val_auc: 0.9915
# Epoch 14/20
# 20/20 [==============================] - 110s 6s/step - loss: 0.1316 - accuracy: 0.9531 - precision: 0.9591 - recall: 0.9531 - auc: 0.9969 - val_loss: 0.1991 - val_accuracy: 0.9335 - val_precision: 0.9385 - val_recall: 0.9315 - val_auc: 0.9921
# Epoch 15/20
# 20/20 [==============================] - 115s 6s/step - loss: 0.1266 - accuracy: 0.9500 - precision: 0.9530 - recall: 0.9500 - auc: 0.9973 - val_loss: 0.2481 - val_accuracy: 0.9115 - val_precision: 0.9168 - val_recall: 0.9085 - val_auc: 0.9889
# Epoch 16/20
# 20/20 [==============================] - 121s 6s/step - loss: 0.0968 - accuracy: 0.9688 - precision: 0.9716 - recall: 0.9625 - auc: 0.9981 - val_loss: 0.1982 - val_accuracy: 0.9300 - val_precision: 0.9368 - val_recall: 0.9260 - val_auc: 0.9914
# Epoch 17/20
# 20/20 [==============================] - 117s 6s/step - loss: 0.1050 - accuracy: 0.9625 - precision: 0.9623 - recall: 0.9563 - auc: 0.9981 - val_loss: 0.1870 - val_accuracy: 0.9365 - val_precision: 0.9406 - val_recall: 0.9335 - val_auc: 0.9927
# Epoch 18/20
# 20/20 [==============================] - 119s 6s/step - loss: 0.0892 - accuracy: 0.9781 - precision: 0.9780 - recall: 0.9719 - auc: 0.9982 - val_loss: 0.1786 - val_accuracy: 0.9330 - val_precision: 0.9390 - val_recall: 0.9305 - val_auc: 0.9933
# Epoch 19/20
# 20/20 [==============================] - 119s 6s/step - loss: 0.0867 - accuracy: 0.9719 - precision: 0.9749 - recall: 0.9719 - auc: 0.9986 - val_loss: 0.2471 - val_accuracy: 0.9180 - val_precision: 0.9223 - val_recall: 0.9145 - val_auc: 0.9887
# Epoch 20/20
# 20/20 [==============================] - 118s 6s/step - loss: 0.1083 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9946 - val_loss: 0.2334 - val_accuracy: 0.9210 - val_precision: 0.9240 - val_recall: 0.9175 - val_auc: 0.9901

# %%
model.evaluate(train_generator)
# Out:
# 200/200 [==============================] - 156s 779ms/step - loss: 0.0535 - accuracy: 0.9791 - precision: 0.9796 - recall: 0.9778 - auc: 0.9993
# [0.053501226007938385,
#  0.9790624976158142,
#  0.9796493649482727,
#  0.9778125286102295,
#  0.9992949962615967]

# %%
model.evaluate(validation_generator)
# Out:
# 125/125 [==============================] - 102s 809ms/step - loss: 0.2428 - accuracy: 0.9180 - precision: 0.9214 - recall: 0.9140 - auc: 0.9886
# [0.24280942976474762,
#  0.9179999828338623,
#  0.9213709831237793,
#  0.9139999747276306,
#  0.9885584115982056]

# %%
model.evaluate(test_generator)
# Out:
# 50/50 [==============================] - 44s 874ms/step - loss: 0.1824 - accuracy: 0.9362 - precision: 0.9396 - recall: 0.9337 - auc: 0.9935
# [0.18237599730491638,
#  0.9362499713897705,
#  0.9396226406097412,
#  0.9337499737739563,
#  0.9934919476509094]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.plot( np.argmin(history.history["val_loss"]), np.min(history.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend()

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(history.history["precision"], label="accuracy")
plt.plot(history.history["val_precision"], label="val_loss")
plt.plot( np.argmin(history.history["val_precision"]), np.min(history.history["val_precision"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("value (log scale)")
plt.legend();

# %%
import keras.utils as image
img = image.load_img("C:/Users/jpsha/Documents/capstone/etest/3_esophagitis/test_esophagitis_ (33).jpg",target_size=(224,224))
imag = image.img_to_array(img)
imaga = np.expand_dims(imag,axis=0) 
ypred = model.predict(imaga)
print(ypred)
a=np.argmax(ypred,-1)
if a==0:
    op="Normal"
elif a==1:
    op="Ulcerative colitis"
elif a==2:
    op="Polyp"
else:
    op="Esophagitis"  

plt.imshow(img)
print("THE UPLOADED IMAGE SEEMS TO BE: "+str(op))
# Out:
# 1/1 [==============================] - 2s 2s/step
# [[2.4901542e-06 7.5244273e-08 3.7511685e-07 9.9999702e-01]]
# THE UPLOADED IMAGE SEEMS TO BE: Esophagitis
